# %%
import sys
sys.path.append('..')

import numpy as np
import matplotlib.pyplot as plt
from michaelmendoza_ssfp import generate_ssfp_dataset, plot_dataset
from michaelmendoza_ssfp.recons import gs_recon, super_fov, rsos

# %%
data = generate_ssfp_dataset(N=128, npcs=6, f=500, alpha=np.deg2rad(60), sigma=0.005, data_indices=[1, 150], rotate=True, deform=True)['M']
plot_dataset(data, slice=0)
print(data.shape)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 55.55it/s]
# Generating 3d phantom:(1, 434, 362)
# (1, 128, 128, 6)

# %%
recon = rsos(data)

# %%
plot_dataset(recon, slice=0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plot_dataset(recon, slice=0)
#
# File ~\projects\mri\ssfp\michaelmendoza_ssfp\plots.py:12, in plot_dataset(data, slice, cmap)
#       9 ''' Plots a slice of dataset of form: [Slice, Height, Width, Channel] '''
#      11 slice = 0 if slice is None else slice
# ---> 12 npcs = data.shape[3]
#      13 nx, ny = 2, int(npcs / 2)
#      14 plt.figure()
#
# IndexError: tuple index out of range
