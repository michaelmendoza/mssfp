# %%
import sys
sys.path.append('..')

import numpy as np
import matplotlib.pyplot as plt
from michaelmendoza_ssfp import generate_ssfp_dataset, plot_dataset
from michaelmendoza_ssfp.recons import gs_recon, super_fov

# %%
data = generate_ssfp_dataset(N=128, npcs=4, f=100, alpha=np.deg2rad(60), sigma=0.005, data_indices=[1, 150], rotate=True, deform=True)['M']
plot_dataset(data, slice=0)
print(data.shape)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 76.93it/s]
# Generating 3d phantom:(1, 434, 362)
# (1, 128, 128, 4)

# %%
recon = super_fov(data, doUndersample = True, doPlot = True)

# %%
recon = gs_recon(data[0], pc_axis=2)

plt.figure()
plt.imshow(np.abs(recon))
plt.title('Reconstructed Image')
plt.xticks([])
plt.yticks([])
plt.show()
