# %%
import sys
sys.path.append('..')

# %%
import math
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

from michaelmendoza_ssfp.mri_ssfp import ma_ssfp, add_noise_gaussian
from michaelmendoza_ssfp.generators import generate_block_phantom2d_ssfp
from michaelmendoza_ssfp.plots import show_dataset

# %%
dataset = generate_block_phantom2d_ssfp()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 128/128 [00:03<00:00, 38.53it/s]

# %%
dataset['M'].shape
# Out:
# (128, 128, 256, 4)

# %%
plt.imshow(np.abs(dataset['M'][0, :, :, 0]))

# %%
Mslice = dataset['M'][0, 32, :, 0]
plt.plot(np.abs(Mslice))

# %%
Mslice = dataset['M'][0, 32+64, :, 0]
plt.plot(np.abs(Mslice))
